# %% [markdown]
# # Data Visualization
# It's an art of representing raw data in the form of beautiful graphs.

# %% [markdown]
# These are tools for data visualization
# - pandas
# - matplotlib(common)
# - seaborn(common)
# - ggplot
# - plotly

# %% [markdown]
# working with so many raw data. so finding insights of these data is extremely hard . so data visualization help us

# %% [markdown]
# Why?
# - Easy to understand graphs
# - better analysis
# - detecting errors
# - efficient
# - good for storytelling
# - quick decision making
# - identify patterns
# - exploring insights

# %% [markdown]
# Types:-
#
#     - Line Graph(-mostly used for short periods
#                 - used to track changes over short and long periods of time.
#                 - also used for more than one group.
#                 - we can compare trends between two or more than two groups.
#                 - also show the relationship between groups.)
#
#     - Bar Graph(- mostly used for long periods of time.)
#
#     - boxplot(-mostly used for detecting the outliers.
#              - it also divides the data into sections like 25%,50%,75% , it also show us the max and min value.
#              - it also help us to find mean of data quickly.)
#
#     - Histogram(-it also groups the data into bins.
#                - used for visualizing both discrete data or continous data.
#                - it also measures the interval of time using bins.
#                - also used this for frequency distribution.)
#
#     - Pie Chart(- show percentage of whole data and represent % at a set point in time.
#                - it don't changes w.r.t time.)
#
#     - Scatter plot(-used for relation and co-relation between each other or not.)

# %% [markdown]
# ## Pandas Visualization

# %%
# working with iris dataset
import pandas as pd
df=pd.read_csv("iris.csv")
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.size
# Out:
# 750

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['sepal length'].sort_values(ascending=False)
# Out:
# 131    7.9
# 135    7.7
# 122    7.7
# 117    7.7
# 118    7.7
#       ...
# 41     4.5
# 42     4.4
# 38     4.4
# 8      4.4
# 13     4.3
# Name: sepal length, Length: 150, dtype: float64

# %%
df.plot(kind="")

# %%
df['sepal length'].plot(kind="line",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# line plot

df['sepal length'].plot(kind="line",figsize=(10,5))
df['petal length'].plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
import numpy as np
df1=pd.DataFrame(np.random.randn(1000),index=pd.date_range('2022-03-29',periods=1000))
df1.head(20)
# Out:
#                    0
# 2022-03-29 -0.423046
# 2022-03-30  0.964846
# 2022-03-31  1.785343
# 2022-04-01  0.303662
# 2022-04-02  1.350754
# 2022-04-03  0.834129
# 2022-04-04 -0.499288
# 2022-04-05 -0.641189
# 2022-04-06  0.720384
# 2022-04-07  0.499579
# 2022-04-08  2.061660
# 2022-04-09 -0.406678
# 2022-04-10 -1.768550
# 2022-04-11 -0.197435
# 2022-04-12  0.368118
# 2022-04-13  0.406043
# 2022-04-14  0.144188
# 2022-04-15  0.728128
# 2022-04-16  1.910861
# 2022-04-17  0.663305

# %%
df1.loc['2022-04-02':"2022-04-17"].plot(kind="line",figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
# bar
df["sepal length"].loc[:40].plot(kind="bar",figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
# box
df.plot(kind='box',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
Q- negative dataframe of 6 columns with 400 indexs-should be in dates, line graph and compare with all other columns.
